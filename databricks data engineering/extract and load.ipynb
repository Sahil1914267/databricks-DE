-- %%
ways to create table

1. pyspark
2. spark sql
 -- ctas
 i. select * from file_format.`path` (single line json, parquet, delta, iceberg)
 ii. select * from read_files(path, file_format => 'csv')

 3. ui (limited)

-- %%
create table dev.demo.customer as select * from parquet.`/Volumes/dev/demo/raw/inputs/part-00006-4ece8039-e05f-4114-8262-9d82c9ee1e62-c000.snappy.parquet`

-- %%
select * from json.`/Volumes/dev/demo/raw/inputs/retail_orders.json`

-- %%
select * from read_files('/Volumes/dev/demo/raw/inputs/retail_orders.json', format => 'json')

-- %%
selelct * from csv.`/Volumes/dev/demo/raw/inputs/financial_dataset.csv`

-- %%
create table dev.demo.transactions as select * from read_files('/Volumes/dev/demo/raw/inputs/financial_dataset.csv', format => 'csv')

-- %%
%python

df = spark.read.csv(
    '/Volumes/dev/demo/raw/inputs/financial_dataset.csv',
    header=True,
    inferSchema=True
)
display(df)

-- %%
df.write.mode('overwrite').saveAsTable('dev.demo.financial_pyspark')
